# %%
import random

def get_questions():
    return [
        {"question": "What is the capital of France?", "options": {"A": "Berlin", "B": "Madrid", "C": "Paris", "D": "Rome"}, "answer": "C"},
        {"question": "Who developed the Python language?", "options": {"A": "Dennis Ritchie", "B": "Guido van Rossum", "C": "James Gosling", "D": "Bjarne Stroustrup"}, "answer": "B"},
        {"question": "What is the chemical symbol for water?", "options": {"A": "H2O", "B": "O2", "C": "CO2", "D": "H2SO4"}, "answer": "A"},
        {"question": "Which planet is known as the Red Planet?", "options": {"A": "Earth", "B": "Mars", "C": "Jupiter", "D": "Venus"}, "answer": "B"},
        {"question": "What is the square root of 64?", "options": {"A": "6", "B": "7", "C": "8", "D": "9"}, "answer": "C"},
    ]

def run_quiz():
    questions = get_questions()
    random.shuffle(questions)  # Randomize question order
    score = 0

    for q in questions:
        print("\n" + q["question"])
        for key, value in q["options"].items():
            print(f"{key}) {value}")

        while True:
            answer = input("Enter your answer (A/B/C/D): ").strip().upper()
            if answer in q["options"].keys():
                break
            print("Invalid input! Please enter A, B, C, or D.")

        if answer == q["answer"]:
            print("Correct!")
            score += 1
        else:
            print(f"Wrong! The correct answer was {q['answer']}) {q['options'][q['answer']]}")

    percentage = (score / len(questions)) * 100
    print(f"\nFinal Score: {percentage:.2f}%")
    if percentage >= 80:
        print("Great job! You have passed the quiz.")
    else:
        print("Better luck next time!")

    restart = input("Would you like to restart the quiz? (yes/no): ").strip().lower()
    if restart == "yes":
        run_quiz()
    else:
        print("Thank you for playing!")

if __name__ == "__main__":
    run_quiz()
# Out:
# Who developed the Python language?
# A) Dennis Ritchie
# B) Guido van Rossum
# C) James Gosling
# D) Bjarne Stroustrup
# Wrong! The correct answer was B) Guido van Rossum
#
# Which planet is known as the Red Planet?
# A) Earth
# B) Mars
# C) Jupiter
# D) Venus
# Correct!
#
# What is the capital of France?
# A) Berlin
# B) Madrid
# C) Paris
# D) Rome
# Correct!
#
# What is the square root of 64?
# A) 6
# B) 7
# C) 8
# D) 9
# Correct!
#
# What is the chemical symbol for water?
# A) H2O
# B) O2
# C) CO2
# D) H2SO4
# Correct!
#
# Final Score: 80.00%
# Great job! You have passed the quiz.
